# %% [markdown]
# # SQL

# %%
from sqlalchemy import create_engine, text
from urllib.parse import quote_plus
import pandas as pd

# Параметры подключения
host = "194.35.48.21"
user = "master-user"
password = "64fjeObn./d,DP][xds"
database = "payments_yakassa"

# Создание движка
engine = create_engine(f"mysql+mysqldb://{user}:%s@{host}/{database}" % quote_plus(password))

# SQL-запрос
query = """
SELECT id, order_id, price, status, created_date, pack_id, pack_identifier_id, user_id, email, device, device_name,
       cancel_reason, is_refund, refund_amount, user_pack_id, platform_id, app_id, is_autopay, is_promo
FROM payments_yakassa
WHERE app_id IN (561, 582)
"""

# Загрузка данных в DataFrame
with engine.connect() as connection:
    df = pd.read_sql(text(query), connection)

print(f"Загружено {len(df)} строк")

# %% [markdown]
# # Недельный

# %%
import pandas as pd
from datetime import datetime, timedelta

FILE_PATH = 'export_(ReportPayments.2025-02-14 - 2025-06-01.).csv'  # путь к CSV-файлу

# === Загрузка данных ===
with open(FILE_PATH, 'r', encoding='utf-8') as f:
    lines = f.readlines()

header_line = lines[10].strip().split(';')
df = pd.read_csv(FILE_PATH, skiprows=11, sep=';', names=header_line)

# === Подготовка ===
df.columns = [col.strip().lower().replace(' ', '_') for col in df.columns]
df['дата'] = pd.to_datetime(df['дата'], errors='coerce')

df = df[
    (df['статус'].str.lower() == 'успешно') &
    (df['e-mail_оплаты'].notnull())
].sort_values(by=['e-mail_оплаты', 'id_пакета', 'дата'])

# === Классификация переходов ===
def classify_transactions(group):
    group = group.sort_values('дата')
    types = []
    promo_found = False
    full_found = False
    for _, row in group.iterrows():
        is_auto = str(row['тип_платежа']).strip().lower() == 'автоплатеж'
        is_promo = row['промо'] == 1
        if is_promo:
            types.append('promo')
            promo_found = True
        elif promo_found and not full_found and is_auto:
            types.append('full')
            full_found = True
        elif full_found and is_auto:
            types.append('repeat')
        else:
            types.append('other')
    group['тип_сделки'] = types
    return group

df = df.groupby(['e-mail_оплаты', 'id_пакета']).apply(classify_transactions).reset_index(drop=True)

# === Только первая автопокупка после промо ===
df = df[df['тип_сделки'] == 'full']
df['год'] = df['дата'].dt.isocalendar().year
df['неделя'] = df['дата'].dt.isocalendar().week

# Пользователь с привязкой к пакету
df['пользователь'] = df['e-mail_оплаты'] + ' — ' + df['девайс_оплаты']

# === Группировка по неделе и пакету ===
grouped = (
    df.groupby(['год', 'неделя', 'пакет'])
    .agg(переходы=('пользователь', lambda x: sorted(set(x))))
    .reset_index()
)

# Добавляем границы недели
def get_week_date_range(year, week):
    start = datetime.fromisocalendar(year, week, 1)
    end = start + timedelta(days=6)
    return start.strftime('%d.%m'), end.strftime('%d.%m')

grouped[['начало_недели', 'конец_недели']] = grouped.apply(
    lambda row: pd.Series(get_week_date_range(row['год'], row['неделя'])),
    axis=1
)

# === Сортировка и вывод ===
grouped = grouped.sort_values(by=['год', 'неделя'], ascending=False)

# === Печать отчёта ===
print("Переходы по неделям и пакетам:\n")
total = 0
for (_, row) in grouped.iterrows():
    count = len(row['переходы'])
    total += count
    print(f"{row['неделя']} Неделя ({row['начало_недели']}–{row['конец_недели']}) — {row['пакет']}: {count}")

print(f"\nВсего переходов: {total}\n")

# Детальный список
for _, row in grouped.iterrows():
    print(f"{row['неделя']} Неделя ({row['начало_недели']}–{row['конец_недели']}) — {row['пакет']}:")
    for u in row['переходы']:
        print(f"  {u}")
    print()
# Out:
# Переходы по неделям и пакетам:
#
# 22 Неделя (26.05–01.06) — PREMIER [477]: 2
# 22 Неделя (26.05–01.06) — START [470]: 3
# 22 Неделя (26.05–01.06) — Мегапикс [456]: 20
# 21 Неделя (19.05–25.05) — PREMIER [477]: 3
# 21 Неделя (19.05–25.05) — START [470]: 5
# 21 Неделя (19.05–25.05) — Мегапикс [456]: 16
# 20 Неделя (12.05–18.05) — PREMIER [477]: 4
# 20 Неделя (12.05–18.05) — Мегапикс [456]: 19
# 19 Неделя (05.05–11.05) — PREMIER [477]: 2
# 19 Неделя (05.05–11.05) — START [470]: 3
# 19 Неделя (05.05–11.05) — Мегапикс [456]: 20
# 18 Неделя (28.04–04.05) — PREMIER [477]: 2
# 18 Неделя (28.04–04.05) — START [470]: 2
# 18 Неделя (28.04–04.05) — Мегапикс [456]: 10
# 17 Неделя (21.04–27.04) — PREMIER [477]: 2
# 17 Неделя (21.04–27.04) — Мегапикс [456]: 11
# 16 Неделя (14.04–20.04) — PREMIER [477]: 3
# 16 Неделя (14.04–20.04) — START [470]: 1
# 16 Неделя (14.04–20.04) — Мегапикс [456]: 14
# 15 Неделя (07.04–13.04) — PREMIER [477]: 2
# 15 Неделя (07.04–13.04) — Мегапикс [456]: 7
# 14 Неделя (31.03–06.04) — PREMIER [477]: 2
# 14 Неделя (31.03–06.04) — Мегапикс [456]: 2
# 13 Неделя (24.03–30.03) — PREMIER [477]: 1
# 13 Неделя (24.03–30.03) — Мегапикс [456]: 3
# 12 Неделя (17.03–23.03) — PREMIER [477]: 1
# 12 Неделя (17.03–23.03) — Мегапикс [456]: 2
# 10 Неделя (03.03–09.03) — Мегапикс [456]: 2
# 8 Неделя (17.02–23.02) — PREMIER [477]: 1
#
# Всего переходов: 165
#
# 22 Неделя (26.05–01.06) — PREMIER [477]:
#   user2146950@limexltd.com — 658c6ed9571c7499
#   user2197525@limexltd.com — 95080a2fc453b5df
#
# 22 Неделя (26.05–01.06) — START [470]:
#   user2146950@limexltd.com — 658c6ed9571c7499
#   user2192639@limexltd.com — 9c2fea0649319a5a
#   user2197525@limexltd.com — 95080a2fc453b5df
#
# 22 Неделя (26.05–01.06) — Мегапикс [456]:
#   user1951580@limexltd.com — 4b7f7ffa82f5f5fa
#   user1968660@limexltd.com — 67d3b9b2b8f01cc0
#   user2062971@limexltd.com — 8f3885c969f665b0
#   user2067304@limexltd.com — b8bd71f66253cfb1
#   user2078168@limexltd.com — 123519a43af3cffe
#   user2143457@limexltd.com — 3593bce2c48eee7e
#   user2146950@limexltd.com — 658c6ed9571c7499
#   user2173249@limexltd.com — dda3379b35abb1c9
#   user2174705@limexltd.com — 56b48819b52ba167
#   user2174957@limexltd.com — 9c6e8f9b6bf68207
#   user2175741@limexltd.com — 39de7b044ab3fa34
#   user2177295@limexltd.com — f55beafab2af475b
#   user2180753@limexltd.com — 9f9e0579f25f1194
#   user2181488@limexltd.com — 333f02aea6ba3dd1
#   user2191183@limexltd.com — fb17695c65476334
#   user2194683@limexltd.com — 1c47bbcc52a46f56
#   user2195698@limexltd.com — ce7ca237b697f490
#   user2196090@limexltd.com — dc128e8609a6c554
#   user2197525@limexltd.com — 95080a2fc453b5df
#   user2202537@limexltd.com — 1ac2c4b87cc0655a
#
# 21 Неделя (19.05–25.05) — PREMIER [477]:
#   user2042559@limexltd.com — 7fa1ec440f50276d
#   user2081500@limexltd.com — 5cc07a327afbd7ad
#   user2086911@limexltd.com — 0c9de34d5c8f95e5
#
# 21 Неделя (19.05–25.05) — START [470]:
#   user1996219@limexltd.com — 571691c7a5d0e773
#   user2081500@limexltd.com — 5cc07a327afbd7ad
#   user2081633@limexltd.com — f3abf8e1419e59c9
#   user2086911@limexltd.com — 0c9de34d5c8f95e5
#   user2157807@limexltd.com — 54f7c434e00ccb61
#
# 21 Неделя (19.05–25.05) — Мегапикс [456]:
#   user1937657@limexltd.com — bb136a24dde15407
#   user1996219@limexltd.com — 571691c7a5d0e773
#   user2016134@limexltd.com — e34856cba4206ac7
#   user2049223@limexltd.com — 1502a4f678b484ef
#   user2081500@limexltd.com — 5cc07a327afbd7ad
#   user2089536@limexltd.com — afdc4724d22d96bd
#   user2124718@limexltd.com — 3a8cc76c159baca5
#   user2135449@limexltd.com — feaacaed2cfde627
#   user2138494@limexltd.com — 553d93d1465bc275
#   user2149575@limexltd.com — 2d5035ab37e5e1b1
#   user2153054@limexltd.com — 06fe145bf7c1b5e6
#   user2155280@limexltd.com — 283f2eaac4776d4e
#   user2157807@limexltd.com — 54f7c434e00ccb61
#   user2158073@limexltd.com — 57ed8ebee3684ddb
#   user2159396@limexltd.com — 675b9552500e4007
#   user2159522@limexltd.com — 205e06b93b843f8e
#
# 20 Неделя (12.05–18.05) — PREMIER [477]:
#   user1997710@limexltd.com — 1ff2e5f148e2d1a0
#   user2081633@limexltd.com — f3abf8e1419e59c9
#   user2100827@limexltd.com — edcdff2cf1a6fd36
#   user2111390@limexltd.com — 8816f5275f15d7e2
#
# 20 Неделя (12.05–18.05) — Мегапикс [456]:
#   user2003548@limexltd.com — d87a4a3101676af4
#   user2018080@limexltd.com — 07923a9431273a66
#   user2028195@limexltd.com — 60693a4c9ec4b0f2
#   user2034404@limexltd.com — f0eba7765905cbe7
#   user2035419@limexltd.com — caf18869878734f8
#   user2036679@limexltd.com — 35d7c654bc561095
#   user2037729@limexltd.com — 0b144409c94f72d8
#   user2091244@limexltd.com — bcfbbcb6b234006b
#   user2095983@limexltd.com — 293043064dc9c536
#   user2100540@limexltd.com — 3f9002b1b1787a70
#   user2100827@limexltd.com — edcdff2cf1a6fd36
#   user2103655@limexltd.com — 666a14050f285414
#   user2105937@limexltd.com — d964e22325561fa9
#   user2106049@limexltd.com — cc661fb02668b08f
#   user2106490@limexltd.com — 18dfee75a99a7bca
#   user2113014@limexltd.com — 651406020d7d220e
#   user2125089@limexltd.com — e108024d4d797ce9
#   user2127658@limexltd.com — ab9eee01e52c163c
#   user2130647@limexltd.com — 6a757ed6e183e7fe
#
# 19 Неделя (05.05–11.05) — PREMIER [477]:
#   user1999964@limexltd.com — cd2fa561deea22bb
#   user2084776@limexltd.com — 66d2267b52485ce8
#
# 19 Неделя (05.05–11.05) — START [470]:
#   user2000062@limexltd.com — 557410aeda7777e3
#   user2006103@limexltd.com — 4d1ef3cd3c48b5c2
#   user2084776@limexltd.com — 66d2267b52485ce8
#
# 19 Неделя (05.05–11.05) — Мегапикс [456]:
#   user1984935@limexltd.com — c59be577438267d3
#   user1999964@limexltd.com — cd2fa561deea22bb
#   user2016141@limexltd.com — 702d3d2afe83aefe
#   user2059569@limexltd.com — fde0e808f8ef7161
#   user2059912@limexltd.com — 25aefc92608dde88
#   user2070643@limexltd.com — 296e497b3ae9b035
#   user2072729@limexltd.com — 67a7bc801d89d669
#   user2073289@limexltd.com — 383ed59dac2f3e31
#   user2073835@limexltd.com — c58e0fce0211e263
#   user2073891@limexltd.com — 2d6ad559d23845c8
#   user2074003@limexltd.com — 674325cb3015a032
#   user2081633@limexltd.com — f3abf8e1419e59c9
#   user2084776@limexltd.com — 66d2267b52485ce8
#   user2087835@limexltd.com — 6079facf3673948d
#   user2088402@limexltd.com — cfcb32425bde01b5
#   user2090201@limexltd.com — dbc63abf008e1f37
#   user2093302@limexltd.com — 7ebd9639be4fcaed
#   user2093610@limexltd.com — d7866c268dd623e5
#   user2096144@limexltd.com — ba186ca78ce19ad1
#   user2098181@limexltd.com — 2d01bd20796af6df
#
# 18 Неделя (28.04–04.05) — PREMIER [477]:
#   user1996219@limexltd.com — 571691c7a5d0e773
#   user2066121@limexltd.com — 257a5e6cfc28d8e6
#
# 18 Неделя (28.04–04.05) — START [470]:
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d
#   user2050119@limexltd.com — 0ed87282d438c8ab
#
# 18 Неделя (28.04–04.05) — Мегапикс [456]:
#   user1893963@limexltd.com — 358f5fbc547003d3
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d
#   user1958818@limexltd.com — dbd3f019e9460bce
#   user1972216@limexltd.com — 535fd2dcbeaea51b
#   user1972370@limexltd.com — 98966d3af474c027
#   user1974519@limexltd.com — c0859f4d7e2ed0c6
#   user1986447@limexltd.com — fea5f563eca2d711
#   user2029448@limexltd.com — 692183193829ad14
#   user2039535@limexltd.com — ba9cac2f66e9b46a
#   user2053577@limexltd.com — d069437365fae0a1
#
# 17 Неделя (21.04–27.04) — PREMIER [477]:
#   user1973966@limexltd.com — 0f38a548f8cd179b
#   user2036679@limexltd.com — 35d7c654bc561095
#
# 17 Неделя (21.04–27.04) — Мегапикс [456]:
#   user1972762@limexltd.com — c15e9f768c2062af
#   user2007447@limexltd.com — 51e1d888eb96c4f2
#   user2029427@limexltd.com — f5f048259ffb3a3e
#   user2030484@limexltd.com — caf6530df567b45f
#   user2030561@limexltd.com — a5a97b4e8cafbc03
#   user2032269@limexltd.com — 6a68ae2425f1361e
#   user2033781@limexltd.com — 31cb2a059b249fdf
#   user2041264@limexltd.com — 3a7f3c98150294e3
#   user2042013@limexltd.com — 8b37077c455e260a
#   user2044365@limexltd.com — d6ade4216d7069ef
#   user2044477@limexltd.com — ed06662f083d63dd
#
# 16 Неделя (14.04–20.04) — PREMIER [477]:
#   user1990346@limexltd.com — 5feb28bfbc52cc96
#   user1998228@limexltd.com — 79883ff0491d8754
#   user2016141@limexltd.com — 702d3d2afe83aefe
#
# 16 Неделя (14.04–20.04) — START [470]:
#   user1997710@limexltd.com — 1ff2e5f148e2d1a0
#
# 16 Неделя (14.04–20.04) — Мегапикс [456]:
#   user1933891@limexltd.com — 12d79bcdb955c5b0
#   user1942494@limexltd.com — e6ef7bc4f0b5931c
#   user1946876@limexltd.com — f4a3e3fbf5685a8
#   user1992530@limexltd.com — 8b315d64ef6e8d5c
#   user1998228@limexltd.com — 79883ff0491d8754
#   user2000223@limexltd.com — eb8db3193378d879
#   user2003114@limexltd.com — 7c6740099601861b
#   user2003744@limexltd.com — b96f7cc16dd43cbf
#   user2003856@limexltd.com — 993f17c99439a9c3
#   user2004423@limexltd.com — d611ca8715809ec9
#   user2008035@limexltd.com — 10f6fb90bbea4405
#   user2015952@limexltd.com — f718b63777b0439d
#   user2016554@limexltd.com — a03d4e1aecf0e33e
#   user2018500@limexltd.com — 523fdbc6610e0872
#
# 15 Неделя (07.04–13.04) — PREMIER [477]:
#   user1990290@limexltd.com — 4264f57ef97be202
#   user2000062@limexltd.com — 557410aeda7777e3
#
# 15 Неделя (07.04–13.04) — Мегапикс [456]:
#   user1988680@limexltd.com — f036010c83d7f64f
#   user1990248@limexltd.com — a45ded42712b05d2
#   user1991333@limexltd.com — 2a2e04e889112c26
#   user1991886@limexltd.com — a673c48952a4ac04
#   user1993377@limexltd.com — e61d0488f1ca6196
#   user1993951@limexltd.com — 1b08a3ebce81f03d
#   user2000062@limexltd.com — 557410aeda7777e3
#
# 14 Неделя (31.03–06.04) — PREMIER [477]:
#   user1898933@limexltd.com — 6910ae281bddfe42
#   user1958314@limexltd.com — f00af1f91fcf341b
#
# 14 Неделя (31.03–06.04) — Мегапикс [456]:
#   user1971824@limexltd.com — eb4ddcef482ca50b
#   user1982408@limexltd.com — f7e7f70f57b7e7f6
#
# 13 Неделя (24.03–30.03) — PREMIER [477]:
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d
#
# 13 Неделя (24.03–30.03) — Мегапикс [456]:
#   user1905709@limexltd.com — 0c18cbdc80100ee1
#   user1907543@limexltd.com — d1844cf885ef0581
#   user1938364@limexltd.com — 425c13cde7991343
#
# 12 Неделя (17.03–23.03) — PREMIER [477]:
#   user1933891@limexltd.com — 12d79bcdb955c5b0
#
# 12 Неделя (17.03–23.03) — Мегапикс [456]:
#   user1892787@limexltd.com — 770ac6ac89b637e8
#   user1918260@limexltd.com — bfc275b41f749f39
#
# 10 Неделя (03.03–09.03) — Мегапикс [456]:
#   sasch.telminov@yandex.ru — f4c31551-6c3f-4bf6-9f64-6fe9e847e41c
#   user1903511@limexltd.com — 41bea2cec9501f3f
#
# 8 Неделя (17.02–23.02) — PREMIER [477]:
#   user1883771@limexltd.com — 3b53116adfc4d266

# %% [markdown]
# # Месячный

# %%
import pandas as pd
from datetime import datetime

FILE_PATH = 'export_(ReportPayments.2025-02-14 - 2025-06-01.).csv'

# === Загрузка данных ===
with open(FILE_PATH, 'r', encoding='utf-8') as f:
    lines = f.readlines()

header_line = lines[10].strip().split(';')
df = pd.read_csv(FILE_PATH, skiprows=11, sep=';', names=header_line)

# === Подготовка ===
df.columns = [col.strip().lower().replace(' ', '_') for col in df.columns]
df['дата'] = pd.to_datetime(df['дата'], errors='coerce')

df = df[
    (df['статус'].str.lower() == 'успешно') &
    (df['e-mail_оплаты'].notnull())
].sort_values(by=['e-mail_оплаты', 'id_пакета', 'дата'])

# === Классификация переходов ===
def classify_transactions(group):
    group = group.sort_values('дата')
    types = []
    promo_found = False
    full_found = False
    for _, row in group.iterrows():
        is_auto = str(row['тип_платежа']).strip().lower() == 'автоплатеж'
        is_promo = row['промо'] == 1
        if is_promo:
            types.append('promo')
            promo_found = True
        elif promo_found and not full_found and is_auto:
            types.append('full')
            full_found = True
        elif full_found and is_auto:
            types.append('repeat')
        else:
            types.append('other')
    group['тип_сделки'] = types
    return group

df = df.groupby(['e-mail_оплаты', 'id_пакета']).apply(classify_transactions).reset_index(drop=True)

# === Только первая автопокупка после промо ===
df = df[df['тип_сделки'] == 'full']
df['год'] = df['дата'].dt.year
df['месяц'] = df['дата'].dt.month
df['месяц_текст'] = df['дата'].dt.strftime('%B')
df['пользователь'] = df['e-mail_оплаты'] + ' — ' + df['девайс_оплаты']

# === Группировка по месяцу и пакету ===
grouped = (
    df.groupby(['год', 'месяц', 'месяц_текст', 'пакет'])
    .agg(
        переходы=('пользователь', lambda x: sorted(set(x)))
    )
    .reset_index()
)

# === Сортировка и вывод ===
grouped = grouped.sort_values(by=['год', 'месяц'], ascending=False)

print("Переходы по месяцам и пакетам:\n")
total = 0
for _, row in grouped.iterrows():
    count = len(row['переходы'])
    total += count
    print(f"{row['месяц_текст']} {row['год']} — {row['пакет']}: {count}")

print(f"\nВсего переходов: {total}\n")

# === Детальный список ===
for _, row in grouped.iterrows():
    print(f"{row['месяц_текст']} {row['год']} — {row['пакет']}:")
    for u in row['переходы']:
        print(f"  {u}")
    print()
# Out:
# Переходы по месяцам и пакетам:
#
# June 2025 — Мегапикс [456]: 2
# May 2025 — PREMIER [477]: 12
# May 2025 — START [470]: 11
# May 2025 — Мегапикс [456]: 76
# April 2025 — PREMIER [477]: 10
# April 2025 — START [470]: 3
# April 2025 — Мегапикс [456]: 41
# March 2025 — PREMIER [477]: 2
# March 2025 — Мегапикс [456]: 7
# February 2025 — PREMIER [477]: 1
#
# Всего переходов: 165
#
# June 2025 — Мегапикс [456]:
#   user2180753@limexltd.com — 9f9e0579f25f1194
#   user2202537@limexltd.com — 1ac2c4b87cc0655a
#
# May 2025 — PREMIER [477]:
#   user1997710@limexltd.com — 1ff2e5f148e2d1a0
#   user1999964@limexltd.com — cd2fa561deea22bb
#   user2042559@limexltd.com — 7fa1ec440f50276d
#   user2066121@limexltd.com — 257a5e6cfc28d8e6
#   user2081500@limexltd.com — 5cc07a327afbd7ad
#   user2081633@limexltd.com — f3abf8e1419e59c9
#   user2084776@limexltd.com — 66d2267b52485ce8
#   user2086911@limexltd.com — 0c9de34d5c8f95e5
#   user2100827@limexltd.com — edcdff2cf1a6fd36
#   user2111390@limexltd.com — 8816f5275f15d7e2
#   user2146950@limexltd.com — 658c6ed9571c7499
#   user2197525@limexltd.com — 95080a2fc453b5df
#
# May 2025 — START [470]:
#   user1996219@limexltd.com — 571691c7a5d0e773
#   user2000062@limexltd.com — 557410aeda7777e3
#   user2006103@limexltd.com — 4d1ef3cd3c48b5c2
#   user2081500@limexltd.com — 5cc07a327afbd7ad
#   user2081633@limexltd.com — f3abf8e1419e59c9
#   user2084776@limexltd.com — 66d2267b52485ce8
#   user2086911@limexltd.com — 0c9de34d5c8f95e5
#   user2146950@limexltd.com — 658c6ed9571c7499
#   user2157807@limexltd.com — 54f7c434e00ccb61
#   user2192639@limexltd.com — 9c2fea0649319a5a
#   user2197525@limexltd.com — 95080a2fc453b5df
#
# May 2025 — Мегапикс [456]:
#   user1893963@limexltd.com — 358f5fbc547003d3
#   user1937657@limexltd.com — bb136a24dde15407
#   user1951580@limexltd.com — 4b7f7ffa82f5f5fa
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d
#   user1968660@limexltd.com — 67d3b9b2b8f01cc0
#   user1984935@limexltd.com — c59be577438267d3
#   user1986447@limexltd.com — fea5f563eca2d711
#   user1996219@limexltd.com — 571691c7a5d0e773
#   user1999964@limexltd.com — cd2fa561deea22bb
#   user2003548@limexltd.com — d87a4a3101676af4
#   user2016134@limexltd.com — e34856cba4206ac7
#   user2016141@limexltd.com — 702d3d2afe83aefe
#   user2018080@limexltd.com — 07923a9431273a66
#   user2028195@limexltd.com — 60693a4c9ec4b0f2
#   user2034404@limexltd.com — f0eba7765905cbe7
#   user2035419@limexltd.com — caf18869878734f8
#   user2036679@limexltd.com — 35d7c654bc561095
#   user2037729@limexltd.com — 0b144409c94f72d8
#   user2049223@limexltd.com — 1502a4f678b484ef
#   user2059569@limexltd.com — fde0e808f8ef7161
#   user2059912@limexltd.com — 25aefc92608dde88
#   user2062971@limexltd.com — 8f3885c969f665b0
#   user2067304@limexltd.com — b8bd71f66253cfb1
#   user2070643@limexltd.com — 296e497b3ae9b035
#   user2072729@limexltd.com — 67a7bc801d89d669
#   user2073289@limexltd.com — 383ed59dac2f3e31
#   user2073835@limexltd.com — c58e0fce0211e263
#   user2073891@limexltd.com — 2d6ad559d23845c8
#   user2074003@limexltd.com — 674325cb3015a032
#   user2078168@limexltd.com — 123519a43af3cffe
#   user2081500@limexltd.com — 5cc07a327afbd7ad
#   user2081633@limexltd.com — f3abf8e1419e59c9
#   user2084776@limexltd.com — 66d2267b52485ce8
#   user2087835@limexltd.com — 6079facf3673948d
#   user2088402@limexltd.com — cfcb32425bde01b5
#   user2089536@limexltd.com — afdc4724d22d96bd
#   user2090201@limexltd.com — dbc63abf008e1f37
#   user2091244@limexltd.com — bcfbbcb6b234006b
#   user2093302@limexltd.com — 7ebd9639be4fcaed
#   user2093610@limexltd.com — d7866c268dd623e5
#   user2095983@limexltd.com — 293043064dc9c536
#   user2096144@limexltd.com — ba186ca78ce19ad1
#   user2098181@limexltd.com — 2d01bd20796af6df
#   user2100540@limexltd.com — 3f9002b1b1787a70
#   user2100827@limexltd.com — edcdff2cf1a6fd36
#   user2103655@limexltd.com — 666a14050f285414
#   user2105937@limexltd.com — d964e22325561fa9
#   user2106049@limexltd.com — cc661fb02668b08f
#   user2106490@limexltd.com — 18dfee75a99a7bca
#   user2113014@limexltd.com — 651406020d7d220e
#   user2124718@limexltd.com — 3a8cc76c159baca5
#   user2125089@limexltd.com — e108024d4d797ce9
#   user2127658@limexltd.com — ab9eee01e52c163c
#   user2130647@limexltd.com — 6a757ed6e183e7fe
#   user2135449@limexltd.com — feaacaed2cfde627
#   user2138494@limexltd.com — 553d93d1465bc275
#   user2143457@limexltd.com — 3593bce2c48eee7e
#   user2146950@limexltd.com — 658c6ed9571c7499
#   user2149575@limexltd.com — 2d5035ab37e5e1b1
#   user2153054@limexltd.com — 06fe145bf7c1b5e6
#   user2155280@limexltd.com — 283f2eaac4776d4e
#   user2157807@limexltd.com — 54f7c434e00ccb61
#   user2158073@limexltd.com — 57ed8ebee3684ddb
#   user2159396@limexltd.com — 675b9552500e4007
#   user2159522@limexltd.com — 205e06b93b843f8e
#   user2173249@limexltd.com — dda3379b35abb1c9
#   user2174705@limexltd.com — 56b48819b52ba167
#   user2174957@limexltd.com — 9c6e8f9b6bf68207
#   user2175741@limexltd.com — 39de7b044ab3fa34
#   user2177295@limexltd.com — f55beafab2af475b
#   user2181488@limexltd.com — 333f02aea6ba3dd1
#   user2191183@limexltd.com — fb17695c65476334
#   user2194683@limexltd.com — 1c47bbcc52a46f56
#   user2195698@limexltd.com — ce7ca237b697f490
#   user2196090@limexltd.com — dc128e8609a6c554
#   user2197525@limexltd.com — 95080a2fc453b5df
#
# April 2025 — PREMIER [477]:
#   user1898933@limexltd.com — 6910ae281bddfe42
#   user1958314@limexltd.com — f00af1f91fcf341b
#   user1973966@limexltd.com — 0f38a548f8cd179b
#   user1990290@limexltd.com — 4264f57ef97be202
#   user1990346@limexltd.com — 5feb28bfbc52cc96
#   user1996219@limexltd.com — 571691c7a5d0e773
#   user1998228@limexltd.com — 79883ff0491d8754
#   user2000062@limexltd.com — 557410aeda7777e3
#   user2016141@limexltd.com — 702d3d2afe83aefe
#   user2036679@limexltd.com — 35d7c654bc561095
#
# April 2025 — START [470]:
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d
#   user1997710@limexltd.com — 1ff2e5f148e2d1a0
#   user2050119@limexltd.com — 0ed87282d438c8ab
#
# April 2025 — Мегапикс [456]:
#   user1933891@limexltd.com — 12d79bcdb955c5b0
#   user1942494@limexltd.com — e6ef7bc4f0b5931c
#   user1946876@limexltd.com — f4a3e3fbf5685a8
#   user1958818@limexltd.com — dbd3f019e9460bce
#   user1971824@limexltd.com — eb4ddcef482ca50b
#   user1972216@limexltd.com — 535fd2dcbeaea51b
#   user1972370@limexltd.com — 98966d3af474c027
#   user1972762@limexltd.com — c15e9f768c2062af
#   user1974519@limexltd.com — c0859f4d7e2ed0c6
#   user1982408@limexltd.com — f7e7f70f57b7e7f6
#   user1988680@limexltd.com — f036010c83d7f64f
#   user1990248@limexltd.com — a45ded42712b05d2
#   user1991333@limexltd.com — 2a2e04e889112c26
#   user1991886@limexltd.com — a673c48952a4ac04
#   user1992530@limexltd.com — 8b315d64ef6e8d5c
#   user1993377@limexltd.com — e61d0488f1ca6196
#   user1993951@limexltd.com — 1b08a3ebce81f03d
#   user1998228@limexltd.com — 79883ff0491d8754
#   user2000062@limexltd.com — 557410aeda7777e3
#   user2000223@limexltd.com — eb8db3193378d879
#   user2003114@limexltd.com — 7c6740099601861b
#   user2003744@limexltd.com — b96f7cc16dd43cbf
#   user2003856@limexltd.com — 993f17c99439a9c3
#   user2004423@limexltd.com — d611ca8715809ec9
#   user2007447@limexltd.com — 51e1d888eb96c4f2
#   user2008035@limexltd.com — 10f6fb90bbea4405
#   user2015952@limexltd.com — f718b63777b0439d
#   user2016554@limexltd.com — a03d4e1aecf0e33e
#   user2018500@limexltd.com — 523fdbc6610e0872
#   user2029427@limexltd.com — f5f048259ffb3a3e
#   user2029448@limexltd.com — 692183193829ad14
#   user2030484@limexltd.com — caf6530df567b45f
#   user2030561@limexltd.com — a5a97b4e8cafbc03
#   user2032269@limexltd.com — 6a68ae2425f1361e
#   user2033781@limexltd.com — 31cb2a059b249fdf
#   user2039535@limexltd.com — ba9cac2f66e9b46a
#   user2041264@limexltd.com — 3a7f3c98150294e3
#   user2042013@limexltd.com — 8b37077c455e260a
#   user2044365@limexltd.com — d6ade4216d7069ef
#   user2044477@limexltd.com — ed06662f083d63dd
#   user2053577@limexltd.com — d069437365fae0a1
#
# March 2025 — PREMIER [477]:
#   user1933891@limexltd.com — 12d79bcdb955c5b0
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d
#
# March 2025 — Мегапикс [456]:
#   sasch.telminov@yandex.ru — f4c31551-6c3f-4bf6-9f64-6fe9e847e41c
#   user1892787@limexltd.com — 770ac6ac89b637e8
#   user1903511@limexltd.com — 41bea2cec9501f3f
#   user1905709@limexltd.com — 0c18cbdc80100ee1
#   user1907543@limexltd.com — d1844cf885ef0581
#   user1918260@limexltd.com — bfc275b41f749f39
#   user1938364@limexltd.com — 425c13cde7991343
#
# February 2025 — PREMIER [477]:
#   user1883771@limexltd.com — 3b53116adfc4d266

# %% [markdown]
# # Табличка с соответствиями

# %%
import pandas as pd
from IPython.display import display

# Пути к файлам
installations_path = "installations.csv"
payments_path = "ReportPayments.2025-05-01 - 2025-05-31.2025-06-03.csv"

# Загрузка CSV
installations_df = pd.read_csv(installations_path)
payments_df = pd.read_csv(payments_path, sep=';')

# Очистка от пустых profile_id
installations_df_clean = installations_df.dropna(subset=['profile_id'])

# Переименование для объединения
installations_df_clean = installations_df_clean.rename(columns={"profile_id": "Девайс оплаты"})

# Объединение по 'Девайс оплаты'
merged_df = payments_df.merge(installations_df_clean, on="Девайс оплаты", how="inner")

# Сбор нужных столбцов и переименование
result_df = merged_df[["Сумма", "Пакет", "Девайс оплаты", "tracker_name"]]
result_df = result_df.rename(columns={"tracker_name": "Трекер"})

# Вывод таблицы
print("Сводная таблица оплат:")
display(result_df)

# Сумма по трекерам
sum_by_tracker = result_df.groupby("Трекер")["Сумма"].sum().reset_index()
sum_by_tracker = sum_by_tracker.sort_values(by="Сумма", ascending=False)

# Сумма и количество платежей по трекерам
tracker_summary = (
    result_df.groupby("Трекер")
    .agg(
        Сумма=('Сумма', 'sum'),
        Платежи=('Сумма', 'count')
    )
    .reset_index()
    .sort_values(by="Сумма", ascending=False)
)

print("\nСумма и количество платежей по каждому трекеру:")
display(tracker_summary)
# Out:
# Сводная таблица оплат:
#     Сумма                Пакет     Девайс оплаты                           Трекер
# 0   349.0            18+ [463]  70b0baaa60d0ea6b   PIX_Android_video_app_mid_roll
# 1   349.0            18+ [463]  5e04048326031cfc                 PIX Android push
# 2   349.0            18+ [463]  a1bb18b3cf1e843c   PIX_Android_video_app_mid_roll
# 3   199.0            КХЛ [484]  66d2267b52485ce8   PIX_Android_video_app_mid_roll
# 4   379.0   Матч! Футбол [498]  66d2267b52485ce8   PIX_Android_video_app_mid_roll
# 5   299.0  Матч! Премьер [491]  66d2267b52485ce8   PIX_Android_video_app_mid_roll
# 6   349.0            18+ [463]  66d2267b52485ce8   PIX_Android_video_app_mid_roll
# 7   349.0            18+ [463]  5cc07a327afbd7ad                      Google Play
# 8   349.0            18+ [463]  5587e741e7daab35  PIX_Direct_10.03.25_Alternative
# 9   349.0            18+ [463]  d9c2c2ebc247b2fa                 PIX Android push
# 10  349.0            18+ [463]  3d7f2f795cf0b077                      Google Play
# 11  349.0            18+ [463]  fd9284f1df2e918a         PIX_Android_Mobile_Pleer
# 12  349.0            18+ [463]  59005b2fcb9e2151                      Google Play
# 13  349.0            18+ [463]  f5d02e3f773d8d42   PIX_Android_video_app_mid_roll
# 14  349.0            18+ [463]  ccb1d30f0585b9d2                      Google Play
# 15  349.0            18+ [463]  7caf2eb43565e7f9                 PIX Android push
# 16  349.0            18+ [463]  4e1300dcec255890   PIX_Android_video_app_mid_roll
# 17  349.0            18+ [463]  4e1300dcec255890   PIX_Android_video_app_mid_roll
# 18  349.0            18+ [463]  fb17695c65476334   PIX_Android_video_app_mid_roll
# 19  349.0            18+ [463]  fecda86c54492ccb   PIX_Android_video_app_mid_roll
# 20  199.0            КХЛ [484]  95080a2fc453b5df                          unknown
# 21  349.0            18+ [463]  dd95cb096bf6a16c                      Google Play
# 22  349.0            18+ [463]  7a662709ea4c2806                      Google Play
# 23  199.0            КХЛ [484]  7d3aa00f4bb80ffc   PIX_Android_video_app_mid_roll
# 24  379.0   Матч! Футбол [498]  7d3aa00f4bb80ffc   PIX_Android_video_app_mid_roll
# 25  199.0            КХЛ [484]  54f7c434e00ccb61   PIX_Android_video_app_mid_roll
# 26  349.0            18+ [463]  74fbbc505bb134aa                      Google Play
# 27  349.0            18+ [463]  cb1eac642d357a84   PIX_Android_video_app_mid_roll
# 28  199.0            КХЛ [484]  571691c7a5d0e773                 PIX Android push
# Сумма и количество платежей по каждому трекеру:
#                             Трекер   Сумма  Платежи
# 3   PIX_Android_video_app_mid_roll  4795.0       15
# 0                      Google Play  2443.0        7
# 1                 PIX Android push  1246.0        4
# 2         PIX_Android_Mobile_Pleer   349.0        1
# 4  PIX_Direct_10.03.25_Alternative   349.0        1
# 5                          unknown   199.0        1

# %% [markdown]
# # Вывод конверсии

# %%
import pandas as pd
from datetime import datetime

# === Пути к файлам ===
PAYMENTS_PATH = 'export_(ReportPayments.2025-02-14 - 2025-06-01.).csv'
INSTALLATIONS_PATH = 'installations.csv'

# === Загрузка платежей ===
with open(PAYMENTS_PATH, 'r', encoding='utf-8') as f:
    lines = f.readlines()

header_line = lines[10].strip().split(';')
df = pd.read_csv(PAYMENTS_PATH, skiprows=11, sep=';', names=header_line)
df.columns = [col.strip().lower().replace(' ', '_') for col in df.columns]
df['дата'] = pd.to_datetime(df['дата'], errors='coerce')

# === Фильтрация успешных платежей ===
df = df[
    (df['статус'].str.lower() == 'успешно') &
    (df['e-mail_оплаты'].notnull())
].sort_values(by=['e-mail_оплаты', 'id_пакета', 'дата'])

# === Классификация переходов ===
def classify_transactions(group):
    group = group.sort_values('дата')
    types = []
    promo_found = False
    full_found = False
    for _, row in group.iterrows():
        is_auto = str(row['тип_платежа']).strip().lower() == 'автоплатеж'
        is_promo = row['промо'] == 1
        if is_promo:
            types.append('promo')
            promo_found = True
        elif promo_found and not full_found and is_auto:
            types.append('full')
            full_found = True
        elif full_found and is_auto:
            types.append('repeat')
        else:
            types.append('other')
    group['тип_сделки'] = types
    return group

df = df.groupby(['e-mail_оплаты', 'id_пакета']).apply(classify_transactions).reset_index(drop=True)

# === Фильтрация только переходов full ===
df = df[df['тип_сделки'] == 'full']

# === Загрузка трекеров ===
install_df = pd.read_csv(INSTALLATIONS_PATH)
install_df = install_df.dropna(subset=['profile_id'])
install_df = install_df.rename(columns={'profile_id': 'девайс_оплаты'})
install_df['tracker_name'] = install_df['tracker_name'].fillna('unknown')

# === Объединение с трекерами ===
df = df.merge(install_df, on='девайс_оплаты', how='left')
df['tracker_name'] = df['tracker_name'].fillna('unknown')

# === Добавление года, месяца и форматированного месяца ===
df['год'] = df['дата'].dt.year
df['месяц'] = df['дата'].dt.month
df['месяц_текст'] = df['дата'].dt.strftime('%B')

# === Создание строки с пользователем и трекером ===
df['пользователь'] = df.apply(
    lambda row: f"{row['e-mail_оплаты']} — {row['девайс_оплаты']} — [{row['tracker_name']}] — {row['сумма']}₽", axis=1
)


# === Группировка по месяцам и пакетам ===
grouped = (
    df.groupby(['год', 'месяц', 'месяц_текст', 'пакет'])
    .agg(переходы=('пользователь', lambda x: sorted(set(x))))
    .reset_index()
    .sort_values(by=['год', 'месяц'], ascending=False)
)

# === Вывод переходов по месяцам и пакетам ===
print("Переходы по месяцам и пакетам:\n")
total = 0
for _, row in grouped.iterrows():
    count = len(row['переходы'])
    total += count
    print(f"{row['месяц_текст']} {row['год']} — {row['пакет']}: {count}")
print(f"\nВсего переходов: {total}\n")

# === Подробный список переходов с трекерами ===
for _, row in grouped.iterrows():
    print(f"{row['месяц_текст']} {row['год']} — {row['пакет']}:")
    for u in row['переходы']:
        print(f"  {u}")
    print()

# === Статистика по трекерам с разбивкой по месяцам ===
monthly_tracker_stats = (
    df.groupby(['год', 'месяц', 'месяц_текст', 'tracker_name'])
    .agg(
        сумма=('сумма', 'sum'),
        количество=('e-mail_оплаты', 'nunique')
    )
    .reset_index()
    .sort_values(by=['год', 'месяц', 'сумма'], ascending=[False, False, False])
)

print("\nСтатистика по трекерам по месяцам:\n")
for _, row in monthly_tracker_stats.iterrows():
    print(f"{row['месяц_текст']} {row['год']} — {row['tracker_name']}: {row['количество']} пользователей, {row['сумма']}₽")
# Out:
# Переходы по месяцам и пакетам:
#
# June 2025 — Мегапикс [456]: 2
# May 2025 — PREMIER [477]: 12
# May 2025 — START [470]: 11
# May 2025 — Мегапикс [456]: 76
# April 2025 — PREMIER [477]: 10
# April 2025 — START [470]: 3
# April 2025 — Мегапикс [456]: 41
# March 2025 — PREMIER [477]: 2
# March 2025 — Мегапикс [456]: 7
# February 2025 — PREMIER [477]: 1
#
# Всего переходов: 165
#
# June 2025 — Мегапикс [456]:
#   user2180753@limexltd.com — 9f9e0579f25f1194 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2202537@limexltd.com — 1ac2c4b87cc0655a — [PIX_Android_video_app_mid_roll] — 649.0₽
#
# May 2025 — PREMIER [477]:
#   user1997710@limexltd.com — 1ff2e5f148e2d1a0 — [Google Play] — 399.0₽
#   user1999964@limexltd.com — cd2fa561deea22bb — [PIX_Android_video_app_mid_roll_Inspector_Gav] — 399.0₽
#   user2042559@limexltd.com — 7fa1ec440f50276d — [Google Play] — 399.0₽
#   user2066121@limexltd.com — 257a5e6cfc28d8e6 — [PIX_Android_video_app_pre_roll] — 399.0₽
#   user2081500@limexltd.com — 5cc07a327afbd7ad — [Google Play] — 399.0₽
#   user2081633@limexltd.com — f3abf8e1419e59c9 — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user2084776@limexltd.com — 66d2267b52485ce8 — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user2086911@limexltd.com — 0c9de34d5c8f95e5 — [Google Play] — 399.0₽
#   user2100827@limexltd.com — edcdff2cf1a6fd36 — [Google Play] — 399.0₽
#   user2111390@limexltd.com — 8816f5275f15d7e2 — [PIX Android push] — 399.0₽
#   user2146950@limexltd.com — 658c6ed9571c7499 — [PIX_Direct_10.03.25_Alternative] — 399.0₽
#   user2197525@limexltd.com — 95080a2fc453b5df — [unknown] — 399.0₽
#
# May 2025 — START [470]:
#   user1996219@limexltd.com — 571691c7a5d0e773 — [PIX Android push] — 499.0₽
#   user2000062@limexltd.com — 557410aeda7777e3 — [PIX_Direct_10.03.25_Alternative] — 499.0₽
#   user2006103@limexltd.com — 4d1ef3cd3c48b5c2 — [Google Play] — 499.0₽
#   user2081500@limexltd.com — 5cc07a327afbd7ad — [Google Play] — 499.0₽
#   user2081633@limexltd.com — f3abf8e1419e59c9 — [PIX_Android_video_app_mid_roll] — 499.0₽
#   user2084776@limexltd.com — 66d2267b52485ce8 — [PIX_Android_video_app_mid_roll] — 499.0₽
#   user2086911@limexltd.com — 0c9de34d5c8f95e5 — [Google Play] — 499.0₽
#   user2146950@limexltd.com — 658c6ed9571c7499 — [PIX_Direct_10.03.25_Alternative] — 499.0₽
#   user2157807@limexltd.com — 54f7c434e00ccb61 — [PIX_Android_video_app_mid_roll] — 499.0₽
#   user2192639@limexltd.com — 9c2fea0649319a5a — [PIX_Direct_10.03.25_Alternative] — 499.0₽
#   user2197525@limexltd.com — 95080a2fc453b5df — [unknown] — 499.0₽
#
# May 2025 — Мегапикс [456]:
#   user1893963@limexltd.com — 358f5fbc547003d3 — [Google Play] — 649.0₽
#   user1937657@limexltd.com — bb136a24dde15407 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1951580@limexltd.com — 4b7f7ffa82f5f5fa — [Google Play] — 649.0₽
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1968660@limexltd.com — 67d3b9b2b8f01cc0 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1984935@limexltd.com — c59be577438267d3 — [unknown] — 649.0₽
#   user1986447@limexltd.com — fea5f563eca2d711 — [Google Play] — 649.0₽
#   user1996219@limexltd.com — 571691c7a5d0e773 — [PIX Android push] — 649.0₽
#   user1999964@limexltd.com — cd2fa561deea22bb — [PIX_Android_video_app_mid_roll_Inspector_Gav] — 649.0₽
#   user2003548@limexltd.com — d87a4a3101676af4 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2016134@limexltd.com — e34856cba4206ac7 — [unknown] — 649.0₽
#   user2016141@limexltd.com — 702d3d2afe83aefe — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2018080@limexltd.com — 07923a9431273a66 — [Google Play] — 649.0₽
#   user2028195@limexltd.com — 60693a4c9ec4b0f2 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2034404@limexltd.com — f0eba7765905cbe7 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2035419@limexltd.com — caf18869878734f8 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2036679@limexltd.com — 35d7c654bc561095 — [Google Play] — 649.0₽
#   user2037729@limexltd.com — 0b144409c94f72d8 — [Google Play] — 649.0₽
#   user2049223@limexltd.com — 1502a4f678b484ef — [unknown] — 649.0₽
#   user2059569@limexltd.com — fde0e808f8ef7161 — [Google Play] — 649.0₽
#   user2059912@limexltd.com — 25aefc92608dde88 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2062971@limexltd.com — 8f3885c969f665b0 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2067304@limexltd.com — b8bd71f66253cfb1 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2070643@limexltd.com — 296e497b3ae9b035 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2072729@limexltd.com — 67a7bc801d89d669 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2073289@limexltd.com — 383ed59dac2f3e31 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2073835@limexltd.com — c58e0fce0211e263 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2073891@limexltd.com — 2d6ad559d23845c8 — [Google Play] — 649.0₽
#   user2074003@limexltd.com — 674325cb3015a032 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2078168@limexltd.com — 123519a43af3cffe — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2081500@limexltd.com — 5cc07a327afbd7ad — [Google Play] — 649.0₽
#   user2081633@limexltd.com — f3abf8e1419e59c9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2084776@limexltd.com — 66d2267b52485ce8 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2087835@limexltd.com — 6079facf3673948d — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2088402@limexltd.com — cfcb32425bde01b5 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2089536@limexltd.com — afdc4724d22d96bd — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2090201@limexltd.com — dbc63abf008e1f37 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2091244@limexltd.com — bcfbbcb6b234006b — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2093302@limexltd.com — 7ebd9639be4fcaed — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2093610@limexltd.com — d7866c268dd623e5 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2095983@limexltd.com — 293043064dc9c536 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2096144@limexltd.com — ba186ca78ce19ad1 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2098181@limexltd.com — 2d01bd20796af6df — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2100540@limexltd.com — 3f9002b1b1787a70 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2100827@limexltd.com — edcdff2cf1a6fd36 — [Google Play] — 649.0₽
#   user2103655@limexltd.com — 666a14050f285414 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2105937@limexltd.com — d964e22325561fa9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2106049@limexltd.com — cc661fb02668b08f — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2106490@limexltd.com — 18dfee75a99a7bca — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2113014@limexltd.com — 651406020d7d220e — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2124718@limexltd.com — 3a8cc76c159baca5 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2125089@limexltd.com — e108024d4d797ce9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2127658@limexltd.com — ab9eee01e52c163c — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2130647@limexltd.com — 6a757ed6e183e7fe — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2135449@limexltd.com — feaacaed2cfde627 — [Google Play] — 649.0₽
#   user2138494@limexltd.com — 553d93d1465bc275 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2143457@limexltd.com — 3593bce2c48eee7e — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2146950@limexltd.com — 658c6ed9571c7499 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2149575@limexltd.com — 2d5035ab37e5e1b1 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2153054@limexltd.com — 06fe145bf7c1b5e6 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2155280@limexltd.com — 283f2eaac4776d4e — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2157807@limexltd.com — 54f7c434e00ccb61 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2158073@limexltd.com — 57ed8ebee3684ddb — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2159396@limexltd.com — 675b9552500e4007 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2159522@limexltd.com — 205e06b93b843f8e — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2173249@limexltd.com — dda3379b35abb1c9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2174705@limexltd.com — 56b48819b52ba167 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2174957@limexltd.com — 9c6e8f9b6bf68207 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2175741@limexltd.com — 39de7b044ab3fa34 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2177295@limexltd.com — f55beafab2af475b — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2181488@limexltd.com — 333f02aea6ba3dd1 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2191183@limexltd.com — fb17695c65476334 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2194683@limexltd.com — 1c47bbcc52a46f56 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2195698@limexltd.com — ce7ca237b697f490 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2196090@limexltd.com — dc128e8609a6c554 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2197525@limexltd.com — 95080a2fc453b5df — [unknown] — 649.0₽
#
# April 2025 — PREMIER [477]:
#   user1898933@limexltd.com — 6910ae281bddfe42 — [unknown] — 399.0₽
#   user1958314@limexltd.com — f00af1f91fcf341b — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user1973966@limexltd.com — 0f38a548f8cd179b — [unknown] — 399.0₽
#   user1990290@limexltd.com — 4264f57ef97be202 — [PIX_Direct_10.03.25_Alternative] — 399.0₽
#   user1990346@limexltd.com — 5feb28bfbc52cc96 — [PIX Android push] — 399.0₽
#   user1996219@limexltd.com — 571691c7a5d0e773 — [PIX Android push] — 399.0₽
#   user1998228@limexltd.com — 79883ff0491d8754 — [PIX_Direct_10.03.25_Alternative] — 399.0₽
#   user2000062@limexltd.com — 557410aeda7777e3 — [PIX_Direct_10.03.25_Alternative] — 399.0₽
#   user2016141@limexltd.com — 702d3d2afe83aefe — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user2036679@limexltd.com — 35d7c654bc561095 — [Google Play] — 399.0₽
#
# April 2025 — START [470]:
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d — [PIX_Android_video_app_mid_roll] — 499.0₽
#   user1997710@limexltd.com — 1ff2e5f148e2d1a0 — [Google Play] — 499.0₽
#   user2050119@limexltd.com — 0ed87282d438c8ab — [Google Play] — 499.0₽
#
# April 2025 — Мегапикс [456]:
#   user1933891@limexltd.com — 12d79bcdb955c5b0 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1942494@limexltd.com — e6ef7bc4f0b5931c — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user1946876@limexltd.com — f4a3e3fbf5685a8 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1958818@limexltd.com — dbd3f019e9460bce — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1971824@limexltd.com — eb4ddcef482ca50b — [PIX Android push] — 649.0₽
#   user1972216@limexltd.com — 535fd2dcbeaea51b — [PIX Android push] — 649.0₽
#   user1972370@limexltd.com — 98966d3af474c027 — [PIX Android push] — 649.0₽
#   user1972762@limexltd.com — c15e9f768c2062af — [PIX Android push] — 649.0₽
#   user1974519@limexltd.com — c0859f4d7e2ed0c6 — [Google Play] — 649.0₽
#   user1982408@limexltd.com — f7e7f70f57b7e7f6 — [Google Play] — 649.0₽
#   user1988680@limexltd.com — f036010c83d7f64f — [Google Play] — 649.0₽
#   user1990248@limexltd.com — a45ded42712b05d2 — [Google Play] — 649.0₽
#   user1991333@limexltd.com — 2a2e04e889112c26 — [PIX Android push] — 649.0₽
#   user1991886@limexltd.com — a673c48952a4ac04 — [PIX Android push] — 649.0₽
#   user1992530@limexltd.com — 8b315d64ef6e8d5c — [unknown] — 649.0₽
#   user1993377@limexltd.com — e61d0488f1ca6196 — [Google Play] — 649.0₽
#   user1993951@limexltd.com — 1b08a3ebce81f03d — [PIX Android push] — 649.0₽
#   user1998228@limexltd.com — 79883ff0491d8754 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2000062@limexltd.com — 557410aeda7777e3 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2000223@limexltd.com — eb8db3193378d879 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2003114@limexltd.com — 7c6740099601861b — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2003744@limexltd.com — b96f7cc16dd43cbf — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2003856@limexltd.com — 993f17c99439a9c3 — [Google Play] — 649.0₽
#   user2004423@limexltd.com — d611ca8715809ec9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2007447@limexltd.com — 51e1d888eb96c4f2 — [unknown] — 649.0₽
#   user2008035@limexltd.com — 10f6fb90bbea4405 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2015952@limexltd.com — f718b63777b0439d — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2016554@limexltd.com — a03d4e1aecf0e33e — [Google Play] — 649.0₽
#   user2018500@limexltd.com — 523fdbc6610e0872 — [unknown] — 649.0₽
#   user2029427@limexltd.com — f5f048259ffb3a3e — [Google Play] — 649.0₽
#   user2029448@limexltd.com — 692183193829ad14 — [Google Play] — 649.0₽
#   user2030484@limexltd.com — caf6530df567b45f — [PIX Android push] — 649.0₽
#   user2030561@limexltd.com — a5a97b4e8cafbc03 — [PIX Android push] — 649.0₽
#   user2032269@limexltd.com — 6a68ae2425f1361e — [Google Play] — 649.0₽
#   user2033781@limexltd.com — 31cb2a059b249fdf — [unknown] — 649.0₽
#   user2039535@limexltd.com — ba9cac2f66e9b46a — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2041264@limexltd.com — 3a7f3c98150294e3 — [Pix_direct_19.02.25] — 649.0₽
#   user2042013@limexltd.com — 8b37077c455e260a — [Google Search] — 649.0₽
#   user2044365@limexltd.com — d6ade4216d7069ef — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2044477@limexltd.com — ed06662f083d63dd — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2053577@limexltd.com — d069437365fae0a1 — [PIX Android push] — 649.0₽
#
# March 2025 — PREMIER [477]:
#   user1933891@limexltd.com — 12d79bcdb955c5b0 — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d — [PIX_Android_video_app_mid_roll] — 399.0₽
#
# March 2025 — Мегапикс [456]:
#   sasch.telminov@yandex.ru — f4c31551-6c3f-4bf6-9f64-6fe9e847e41c — [unknown] — 649.0₽
#   user1892787@limexltd.com — 770ac6ac89b637e8 — [unknown] — 649.0₽
#   user1903511@limexltd.com — 41bea2cec9501f3f — [unknown] — 649.0₽
#   user1905709@limexltd.com — 0c18cbdc80100ee1 — [unknown] — 649.0₽
#   user1907543@limexltd.com — d1844cf885ef0581 — [unknown] — 649.0₽
#   user1918260@limexltd.com — bfc275b41f749f39 — [unknown] — 649.0₽
#   user1938364@limexltd.com — 425c13cde7991343 — [unknown] — 649.0₽
#
# February 2025 — PREMIER [477]:
#   user1883771@limexltd.com — 3b53116adfc4d266 — [unknown] — 399.0₽
#
#
# Статистика по трекерам по месяцам:
#
# June 2025 — PIX_Android_video_app_mid_roll: 2 пользователей, 1298.0₽
# May 2025 — PIX_Android_video_app_mid_roll: 53 пользователей, 39288.0₽
# May 2025 — Google Play: 15 пользователей, 11280.0₽
# May 2025 — PIX_Direct_10.03.25_Alternative: 8 пользователей, 7337.0₽
# May 2025 — unknown: 4 пользователей, 3494.0₽
# May 2025 — PIX Android push: 2 пользователей, 1547.0₽
# May 2025 — PIX_Android_video_app_mid_roll_Inspector_Gav: 1 пользователей, 1048.0₽
# May 2025 — PIX_Android_video_app_pre_roll: 1 пользователей, 399.0₽
# April 2025 — Google Play: 13 пользователей, 9185.0₽
# April 2025 — PIX_Android_video_app_mid_roll: 14 пользователей, 8835.0₽
# April 2025 — PIX Android push: 12 пользователей, 7288.0₽
# April 2025 — unknown: 6 пользователей, 4043.0₽
# April 2025 — PIX_Direct_10.03.25_Alternative: 5 пользователей, 3793.0₽
# April 2025 — Google Search: 1 пользователей, 649.0₽
# April 2025 — Pix_direct_19.02.25: 1 пользователей, 649.0₽
# March 2025 — unknown: 7 пользователей, 4543.0₽
# March 2025 — PIX_Android_video_app_mid_roll: 2 пользователей, 798.0₽
# February 2025 — unknown: 1 пользователей, 399.0₽

# %% [markdown]
# # Вывод повторных

# %%
import pandas as pd
import re

# === Загрузка файлов ===
df = pd.read_csv("ReportPayments.csv", sep=';')
installs_df = pd.read_csv("installations.csv")

# === Полный список исключённых пользователей ===
excluded_block = """
user1997710@limexltd.com — 1ff2e5f148e2d1a0
user1999964@limexltd.com — cd2fa561deea22bb
user2042559@limexltd.com — 7fa1ec440f50276d
user2066121@limexltd.com — 257a5e6cfc28d8e6
user2081500@limexltd.com — 5cc07a327afbd7ad
user2081633@limexltd.com — f3abf8e1419e59c9
user2084776@limexltd.com — 66d2267b52485ce8
user2086911@limexltd.com — 0c9de34d5c8f95e5
user2100827@limexltd.com — edcdff2cf1a6fd36
user2111390@limexltd.com — 8816f5275f15d7e2
user2146950@limexltd.com — 658c6ed9571c7499
user2197525@limexltd.com — 95080a2fc453b5df
user1996219@limexltd.com — 571691c7a5d0e773
user2000062@limexltd.com — 557410aeda7777e3
user2006103@limexltd.com — 4d1ef3cd3c48b5c2
user2157807@limexltd.com — 54f7c434e00ccb61
user2192639@limexltd.com — 9c2fea0649319a5a
user1937657@limexltd.com — bb136a24dde15407
user1951580@limexltd.com — 4b7f7ffa82f5f5fa
user1952308@limexltd.com — b5a6b4c8d5dd0f7d
user1968660@limexltd.com — 67d3b9b2b8f01cc0
user1984935@limexltd.com — c59be577438267d3
user1986447@limexltd.com — fea5f563eca2d711
user2003548@limexltd.com — d87a4a3101676af4
user2016134@limexltd.com — e34856cba4206ac7
user2016141@limexltd.com — 702d3d2afe83aefe
user2018080@limexltd.com — 07923a9431273a66
user2028195@limexltd.com — 60693a4c9ec4b0f2
user2034404@limexltd.com — f0eba7765905cbe7
user2035419@limexltd.com — caf18869878734f8
user2036679@limexltd.com — 35d7c654bc561095
user2037729@limexltd.com — 0b144409c94f72d8
user2049223@limexltd.com — 1502a4f678b484ef
user2059569@limexltd.com — fde0e808f8ef7161
user2059912@limexltd.com — 25aefc92608dde88
user2062971@limexltd.com — 8f3885c969f665b0
user2067304@limexltd.com — b8bd71f66253cfb1
user2070643@limexltd.com — 296e497b3ae9b035
user2072729@limexltd.com — 67a7bc801d89d669
user2073289@limexltd.com — 383ed59dac2f3e31
user2073835@limexltd.com — c58e0fce0211e263
user2073891@limexltd.com — 2d6ad559d23845c8
user2074003@limexltd.com — 674325cb3015a032
user2078168@limexltd.com — 123519a43af3cffe
user2087835@limexltd.com — 6079facf3673948d
user2088402@limexltd.com — cfcb32425bde01b5
user2089536@limexltd.com — afdc4724d22d96bd
user2090201@limexltd.com — dbc63abf008e1f37
user2091244@limexltd.com — bcfbbcb6b234006b
user2093302@limexltd.com — 7ebd9639be4fcaed
user2093610@limexltd.com — d7866c268dd623e5
user2095983@limexltd.com — 293043064dc9c536
user2096144@limexltd.com — ba186ca78ce19ad1
user2098181@limexltd.com — 2d01bd20796af6df
user2100540@limexltd.com — 3f9002b1b1787a70
user2103655@limexltd.com — 666a14050f285414
user2105937@limexltd.com — d964e22325561fa9
user2106049@limexltd.com — cc661fb02668b08f
user2106490@limexltd.com — 18dfee75a99a7bca
user2113014@limexltd.com — 651406020d7d220e
user2124718@limexltd.com — 3a8cc76c159baca5
user2125089@limexltd.com — e108024d4d797ce9
user2127658@limexltd.com — ab9eee01e52c163c
user2130647@limexltd.com — 6a757ed6e183e7fe
user2135449@limexltd.com — feaacaed2cfde627
user2138494@limexltd.com — 553d93d1465bc275
user2143457@limexltd.com — 3593bce2c48eee7e
user2149575@limexltd.com — 2d5035ab37e5e1b1
user2153054@limexltd.com — 06fe145bf7c1b5e6
user2155280@limexltd.com — 283f2eaac4776d4e
user2158073@limexltd.com — 57ed8ebee3684ddb
user2159396@limexltd.com — 675b9552500e4007
user2159522@limexltd.com — 205e06b93b843f8e
user2173249@limexltd.com — dda3379b35abb1c9
user2174705@limexltd.com — 56b48819b52ba167
user2174957@limexltd.com — 9c6e8f9b6bf68207
user2175741@limexltd.com — 39de7b044ab3fa34
user2177295@limexltd.com — f55beafab2af475b
user2181488@limexltd.com — 333f02aea6ba3dd1
user2191183@limexltd.com — fb17695c65476334
user2194683@limexltd.com — 1c47bbcc52a46f56
user2195698@limexltd.com — ce7ca237b697f490
user2196090@limexltd.com — dc128e8609a6c554
"""

excluded = set(re.findall(r'(\S+@limexltd\.com)\s+—\s+([0-9a-f]+)', excluded_block))

# === Удаление исключённых пользователей ===
df_filtered = df[~df.apply(lambda row: (row['E-mail оплаты'], row['Девайс оплаты']) in excluded, axis=1)]

# === Извлечение "старого" трекера (если не будет найден) ===
df_filtered['tracker'] = df_filtered['Приложение'].str.extract(r'\|\s*(.*)')

# === Слияние с installations.csv по device_id ===
merged_df = df_filtered.merge(installs_df, left_on='Девайс оплаты', right_on='profile_id', how='left')

# === Приоритетный трекер — из installations.csv ===
merged_df['tracker_final'] = merged_df['tracker_name'].combine_first(merged_df['tracker'])

# === Формат результата ===
merged_df['output'] = merged_df.apply(
    lambda row: f"{row['E-mail оплаты']} — {row['Девайс оплаты']} — [{row['tracker_final']}] — {row['Сумма']}₽",
    axis=1
)

# === Вывод в консоль ===
for line in merged_df['output']:
    print(line)
    
# === Преобразуем дату в формат datetime и выделим месяц ===
merged_df['Дата'] = pd.to_datetime(merged_df['Дата'], errors='coerce')
merged_df['Месяц'] = merged_df['Дата'].dt.strftime('%B %Y')

# === Группировка по Месяц и tracker_final ===
stats = (
    merged_df.groupby(['Месяц', 'tracker_final'])
    .agg(пользователей=('E-mail оплаты', 'nunique'), сумма_руб=('Сумма', 'sum'))
    .reset_index()
    .sort_values(['Месяц', 'tracker_final'])
)

# === Вывод статистики в консоль ===
print("\nСтатистика по трекерам по месяцам:\n")
for _, row in stats.iterrows():
    print(f"{row['Месяц']} — {row['tracker_final']}: {row['пользователей']} пользователей, {row['сумма_руб']}₽")
# Out:
# user1893963@limexltd.com — 358f5fbc547003d3 — [Google Play] — 649.0₽
# sasch.telminov@yandex.ru — f4c31551-6c3f-4bf6-9f64-6fe9e847e41c — [Pix-SVOD] — 649.0₽
# user1903511@limexltd.com — 41bea2cec9501f3f — [Pix-Svod] — 649.0₽
# efremovaelis7@gmail.com — c76d3e9d-17a5-4f7e-8948-e4cc0271717a — [Pix-SVOD] — 349.0₽
# user1990248@limexltd.com — a45ded42712b05d2 — [Google Play] — 649.0₽
# user1993377@limexltd.com — e61d0488f1ca6196 — [Google Play] — 649.0₽
# user1933891@limexltd.com — 12d79bcdb955c5b0 — [PIX_Android_video_app_mid_roll] — 649.0₽
# user2003856@limexltd.com — 993f17c99439a9c3 — [Google Play] — 649.0₽
# user2003744@limexltd.com — b96f7cc16dd43cbf — [PIX_Android_video_app_mid_roll] — 649.0₽
# user2003114@limexltd.com — 7c6740099601861b — [PIX_Android_video_app_mid_roll] — 649.0₽
# user2008035@limexltd.com — 10f6fb90bbea4405 — [PIX_Android_video_app_mid_roll] — 649.0₽
# user1990346@limexltd.com — 5feb28bfbc52cc96 — [PIX Android push] — 399.0₽
# vasemin36@gmail.com — a0ab05e5-6d2f-4031-ac37-350c20fd7586 — [Pix-SVOD] — 349.0₽
# user2000223@limexltd.com — eb8db3193378d879 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
# user2016554@limexltd.com — a03d4e1aecf0e33e — [Google Play] — 649.0₽
# user1946876@limexltd.com — f4a3e3fbf5685a8 — [PIX_Android_video_app_mid_roll] — 649.0₽
# user1942291@limexltd.com — de9c160dbb8c516e — [Google Play] — 399.0₽
# user1942291@limexltd.com — de9c160dbb8c516e — [Google Play] — 399.0₽
# user1942291@limexltd.com — de9c160dbb8c516e — [Google Play] — 399.0₽
# user1942291@limexltd.com — de9c160dbb8c516e — [Google Play] — 399.0₽
# user1942291@limexltd.com — de9c160dbb8c516e — [Google Play] — 399.0₽
# user1942291@limexltd.com — de9c160dbb8c516e — [Google Play] — 399.0₽
# user1942291@limexltd.com — de9c160dbb8c516e — [Google Play] — 399.0₽
# user1942494@limexltd.com — e6ef7bc4f0b5931c — [PIX_Direct_10.03.25_Alternative] — 649.0₽
# user1883771@limexltd.com — 3b53116adfc4d266 — [Pix-Svod] — 399.0₽
# user1892787@limexltd.com — 770ac6ac89b637e8 — [Pix-Svod] — 649.0₽
# sasch.telminov@yandex.ru — f4c31551-6c3f-4bf6-9f64-6fe9e847e41c — [Pix-SVOD] — 349.0₽
# user1933891@limexltd.com — 12d79bcdb955c5b0 — [PIX_Android_video_app_mid_roll] — 399.0₽
# user1897519@limexltd.com — b09c8a5293a5cc59 — [Pix-Svod] — 349.0₽
# user2051603@limexltd.com — 6c16d2b0e92ab3c1 — [PIX Android баннеры] — 349.0₽
# user2030484@limexltd.com — caf6530df567b45f — [PIX Android push] — 649.0₽
# user2030561@limexltd.com — a5a97b4e8cafbc03 — [PIX Android push] — 649.0₽
# user2054319@limexltd.com — 065045534dcdc656 — [Google Play] — 349.0₽
# user1900291@limexltd.com — 777fc704f649055e — [Pix-Svod] — 349.0₽
# user2033781@limexltd.com — 31cb2a059b249fdf — [Pix-Svod] — 649.0₽
# user2007447@limexltd.com — 51e1d888eb96c4f2 — [unknown] — 649.0₽
# user2032269@limexltd.com — 6a68ae2425f1361e — [Google Play] — 649.0₽
# user1972762@limexltd.com — c15e9f768c2062af — [PIX Android push] — 649.0₽
# user1938364@limexltd.com — 425c13cde7991343 — [Pix-Svod] — 649.0₽
# user1905709@limexltd.com — 0c18cbdc80100ee1 — [Pix-Svod] — 649.0₽
# user1974169@limexltd.com — 7a662709ea4c2806 — [Google Play] — 349.0₽
# user2041264@limexltd.com — 3a7f3c98150294e3 — [Pix_direct_19.02.25] — 649.0₽
# user2042013@limexltd.com — 8b37077c455e260a — [Google Search] — 649.0₽
# user1973966@limexltd.com — 0f38a548f8cd179b — [Pix-Svod] — 399.0₽
# user2029427@limexltd.com — f5f048259ffb3a3e — [Google Play] — 649.0₽
# Merzavecff210@gmail.com — 05e7c145-c2a0-48e3-b6f9-5515f46aa874 — [Pix-SVOD] — 199.0₽
# user1972216@limexltd.com — 535fd2dcbeaea51b — [PIX Android push] — 649.0₽
# user1958818@limexltd.com — dbd3f019e9460bce — [PIX_Android_video_app_mid_roll] — 649.0₽
# user2050119@limexltd.com — 0ed87282d438c8ab — [Google Play] — 499.0₽
# user2053577@limexltd.com — d069437365fae0a1 — [PIX Android push] — 649.0₽
# user1972370@limexltd.com — 98966d3af474c027 — [PIX Android push] — 649.0₽
#
# Статистика по трекерам по месяцам:
#
# May 2025 — Google Play: 11 пользователей, 8533.0₽
# May 2025 — Google Search: 1 пользователей, 649.0₽
# May 2025 — PIX Android push: 7 пользователей, 4293.0₽
# May 2025 — PIX Android баннеры: 1 пользователей, 349.0₽
# May 2025 — PIX_Android_video_app_mid_roll: 6 пользователей, 4293.0₽
# May 2025 — PIX_Direct_10.03.25_Alternative: 2 пользователей, 1298.0₽
# May 2025 — Pix-SVOD: 4 пользователей, 1895.0₽
# May 2025 — Pix-Svod: 9 пользователей, 4741.0₽
# May 2025 — Pix_direct_19.02.25: 1 пользователей, 649.0₽
# May 2025 — unknown: 1 пользователей, 649.0₽
# C:\Users\Аналитик\AppData\Local\Temp\ipykernel_15332\3786468489.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['tracker'] = df_filtered['Приложение'].str.extract(r'\|\s*(.*)')

# %%
import pandas as pd
from datetime import datetime

# === Пути к файлам ===
PAYMENTS_PATH = 'export_(ReportPayments.2025-02-14 - 2025-06-01.).csv'
INSTALLATIONS_PATH = 'installations.csv'

# === Загрузка платежей ===
with open(PAYMENTS_PATH, 'r', encoding='utf-8') as f:
    lines = f.readlines()

header_line = lines[10].strip().split(';')
df = pd.read_csv(PAYMENTS_PATH, skiprows=11, sep=';', names=header_line)
df.columns = [col.strip().lower().replace(' ', '_') for col in df.columns]
df['дата'] = pd.to_datetime(df['дата'], errors='coerce')

# === Фильтрация успешных платежей ===
df = df[
    (df['статус'].str.lower() == 'успешно') &
    (df['e-mail_оплаты'].notnull())
].sort_values(by=['e-mail_оплаты', 'id_пакета', 'дата'])

# === Классификация переходов ===
def classify_transactions(group):
    group = group.sort_values('дата')
    types = []
    full_found = False

    for _, row in group.iterrows():
        is_auto = str(row['тип_платежа']).strip().lower() == 'автоплатеж'
        is_promo = row['промо'] == 1

        if is_promo:
            types.append('promo')
        elif not full_found and is_auto:
            types.append('full')
            full_found = True
        elif full_found and is_auto:
            types.append('repeat')
        else:
            types.append('other')
    group['тип_сделки'] = types
    return group

df = df.groupby(['e-mail_оплаты', 'id_пакета']).apply(classify_transactions).reset_index(drop=True)

# === Повторные платежи ===
repeat_df = df[df['тип_сделки'] == 'repeat'].copy()

# === Оставляем только full-переходы для переходной статистики ===
df = df[df['тип_сделки'] == 'full']

# === Загрузка трекеров ===
install_df = pd.read_csv(INSTALLATIONS_PATH)
install_df = install_df.dropna(subset=['profile_id'])
install_df = install_df.rename(columns={'profile_id': 'девайс_оплаты'})
install_df['tracker_name'] = install_df['tracker_name'].fillna('unknown')

# === Объединение с трекерами ===
df = df.merge(install_df, on='девайс_оплаты', how='left')
df['tracker_name'] = df['tracker_name'].fillna('unknown')

repeat_df = repeat_df.merge(install_df, on='девайс_оплаты', how='left')
repeat_df['tracker_name'] = repeat_df['tracker_name'].fillna('unknown')

# === Добавление года, месяца и форматированного месяца ===
for target_df in [df, repeat_df]:
    target_df['год'] = target_df['дата'].dt.year
    target_df['месяц'] = target_df['дата'].dt.month
    target_df['месяц_текст'] = target_df['дата'].dt.strftime('%B')

# === Создание строки с пользователем и трекером ===
df['пользователь'] = df.apply(
    lambda row: f"{row['e-mail_оплаты']} — {row['девайс_оплаты']} — [{row['tracker_name']}] — {row['сумма']}₽", axis=1
)

# === Группировка по месяцам и пакетам (full only) ===
grouped = (
    df.groupby(['год', 'месяц', 'месяц_текст', 'пакет'])
    .agg(переходы=('пользователь', lambda x: sorted(set(x))))
    .reset_index()
    .sort_values(by=['год', 'месяц'], ascending=False)
)

# === Вывод переходов по месяцам и пакетам ===
print("Переходы по месяцам и пакетам:\n")
total = 0
for _, row in grouped.iterrows():
    count = len(row['переходы'])
    total += count
    print(f"{row['месяц_текст']} {row['год']} — {row['пакет']}: {count}")
print(f"\nВсего переходов: {total}\n")

# === Подробный список переходов с трекерами ===
for _, row in grouped.iterrows():
    print(f"{row['месяц_текст']} {row['год']} — {row['пакет']}:")
    for u in row['переходы']:
        print(f"  {u}")
    print()

# === Статистика по трекерам с разбивкой по месяцам (FULL) ===
print("\nСтатистика по трекерам (переходы full) по месяцам:\n")
monthly_tracker_stats = (
    df.groupby(['год', 'месяц', 'месяц_текст', 'tracker_name'])
    .agg(
        сумма=('сумма', 'sum'),
        количество=('e-mail_оплаты', 'nunique')
    )
    .reset_index()
    .sort_values(by=['год', 'месяц', 'сумма'], ascending=[False, False, False])
)

for _, row in monthly_tracker_stats.iterrows():
    print(f"{row['месяц_текст']} {row['год']} — {row['tracker_name']}: {row['количество']} пользователей, {row['сумма']}₽")

# === Статистика по повторным платежам (repeat) ===
print("\nСтатистика по повторным платежам (repeat) по месяцам и трекерам:\n")
repeat_stats = (
    repeat_df.groupby(['год', 'месяц', 'месяц_текст', 'tracker_name'])
    .agg(
        сумма=('сумма', 'sum'),
        количество=('e-mail_оплаты', 'count')  # здесь считаем каждую запись как один повтор
    )
    .reset_index()
    .sort_values(by=['год', 'месяц', 'сумма'], ascending=[False, False, False])
)

for _, row in repeat_stats.iterrows():
    print(f"{row['месяц_текст']} {row['год']} — {row['tracker_name']}: {row['количество']} повторных платежей, {row['сумма']}₽")
# Out:
# Переходы по месяцам и пакетам:
#
# June 2025 — Мегапикс [456]: 2
# May 2025 — 18+ [463]: 3
# May 2025 — PREMIER [477]: 12
# May 2025 — START [470]: 11
# May 2025 — КХЛ [484]: 1
# May 2025 — Мегапикс [456]: 76
# April 2025 — 18+ [463]: 3
# April 2025 — PREMIER [477]: 12
# April 2025 — START [470]: 3
# April 2025 — Мегапикс [456]: 41
# March 2025 — 18+ [463]: 3
# March 2025 — PREMIER [477]: 2
# March 2025 — КХЛ [484]: 1
# March 2025 — Мегапикс [456]: 7
# February 2025 — PREMIER [477]: 1
#
# Всего переходов: 178
#
# June 2025 — Мегапикс [456]:
#   user2180753@limexltd.com — 9f9e0579f25f1194 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2202537@limexltd.com — 1ac2c4b87cc0655a — [PIX_Android_video_app_mid_roll] — 649.0₽
#
# May 2025 — 18+ [463]:
#   user1996219@limexltd.com — 571691c7a5d0e773 — [PIX Android push] — 349.0₽
#   user2051603@limexltd.com — 6c16d2b0e92ab3c1 — [PIX Android баннеры] — 349.0₽
#   user2054319@limexltd.com — 065045534dcdc656 — [Google Play] — 349.0₽
#
# May 2025 — PREMIER [477]:
#   user1997710@limexltd.com — 1ff2e5f148e2d1a0 — [Google Play] — 399.0₽
#   user1999964@limexltd.com — cd2fa561deea22bb — [PIX_Android_video_app_mid_roll_Inspector_Gav] — 399.0₽
#   user2042559@limexltd.com — 7fa1ec440f50276d — [Google Play] — 399.0₽
#   user2066121@limexltd.com — 257a5e6cfc28d8e6 — [PIX_Android_video_app_pre_roll] — 399.0₽
#   user2081500@limexltd.com — 5cc07a327afbd7ad — [Google Play] — 399.0₽
#   user2081633@limexltd.com — f3abf8e1419e59c9 — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user2084776@limexltd.com — 66d2267b52485ce8 — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user2086911@limexltd.com — 0c9de34d5c8f95e5 — [Google Play] — 399.0₽
#   user2100827@limexltd.com — edcdff2cf1a6fd36 — [Google Play] — 399.0₽
#   user2111390@limexltd.com — 8816f5275f15d7e2 — [PIX Android push] — 399.0₽
#   user2146950@limexltd.com — 658c6ed9571c7499 — [PIX_Direct_10.03.25_Alternative] — 399.0₽
#   user2197525@limexltd.com — 95080a2fc453b5df — [unknown] — 399.0₽
#
# May 2025 — START [470]:
#   user1996219@limexltd.com — 571691c7a5d0e773 — [PIX Android push] — 499.0₽
#   user2000062@limexltd.com — 557410aeda7777e3 — [PIX_Direct_10.03.25_Alternative] — 499.0₽
#   user2006103@limexltd.com — 4d1ef3cd3c48b5c2 — [Google Play] — 499.0₽
#   user2081500@limexltd.com — 5cc07a327afbd7ad — [Google Play] — 499.0₽
#   user2081633@limexltd.com — f3abf8e1419e59c9 — [PIX_Android_video_app_mid_roll] — 499.0₽
#   user2084776@limexltd.com — 66d2267b52485ce8 — [PIX_Android_video_app_mid_roll] — 499.0₽
#   user2086911@limexltd.com — 0c9de34d5c8f95e5 — [Google Play] — 499.0₽
#   user2146950@limexltd.com — 658c6ed9571c7499 — [PIX_Direct_10.03.25_Alternative] — 499.0₽
#   user2157807@limexltd.com — 54f7c434e00ccb61 — [PIX_Android_video_app_mid_roll] — 499.0₽
#   user2192639@limexltd.com — 9c2fea0649319a5a — [PIX_Direct_10.03.25_Alternative] — 499.0₽
#   user2197525@limexltd.com — 95080a2fc453b5df — [unknown] — 499.0₽
#
# May 2025 — КХЛ [484]:
#   user2000062@limexltd.com — 557410aeda7777e3 — [PIX_Direct_10.03.25_Alternative] — 199.0₽
#
# May 2025 — Мегапикс [456]:
#   user1893963@limexltd.com — 358f5fbc547003d3 — [Google Play] — 649.0₽
#   user1937657@limexltd.com — bb136a24dde15407 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1951580@limexltd.com — 4b7f7ffa82f5f5fa — [Google Play] — 649.0₽
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1968660@limexltd.com — 67d3b9b2b8f01cc0 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1984935@limexltd.com — c59be577438267d3 — [unknown] — 649.0₽
#   user1986447@limexltd.com — fea5f563eca2d711 — [Google Play] — 649.0₽
#   user1996219@limexltd.com — 571691c7a5d0e773 — [PIX Android push] — 649.0₽
#   user1999964@limexltd.com — cd2fa561deea22bb — [PIX_Android_video_app_mid_roll_Inspector_Gav] — 649.0₽
#   user2003548@limexltd.com — d87a4a3101676af4 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2016134@limexltd.com — e34856cba4206ac7 — [unknown] — 649.0₽
#   user2016141@limexltd.com — 702d3d2afe83aefe — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2018080@limexltd.com — 07923a9431273a66 — [Google Play] — 649.0₽
#   user2028195@limexltd.com — 60693a4c9ec4b0f2 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2034404@limexltd.com — f0eba7765905cbe7 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2035419@limexltd.com — caf18869878734f8 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2036679@limexltd.com — 35d7c654bc561095 — [Google Play] — 649.0₽
#   user2037729@limexltd.com — 0b144409c94f72d8 — [Google Play] — 649.0₽
#   user2049223@limexltd.com — 1502a4f678b484ef — [unknown] — 649.0₽
#   user2059569@limexltd.com — fde0e808f8ef7161 — [Google Play] — 649.0₽
#   user2059912@limexltd.com — 25aefc92608dde88 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2062971@limexltd.com — 8f3885c969f665b0 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2067304@limexltd.com — b8bd71f66253cfb1 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2070643@limexltd.com — 296e497b3ae9b035 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2072729@limexltd.com — 67a7bc801d89d669 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2073289@limexltd.com — 383ed59dac2f3e31 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2073835@limexltd.com — c58e0fce0211e263 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2073891@limexltd.com — 2d6ad559d23845c8 — [Google Play] — 649.0₽
#   user2074003@limexltd.com — 674325cb3015a032 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2078168@limexltd.com — 123519a43af3cffe — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2081500@limexltd.com — 5cc07a327afbd7ad — [Google Play] — 649.0₽
#   user2081633@limexltd.com — f3abf8e1419e59c9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2084776@limexltd.com — 66d2267b52485ce8 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2087835@limexltd.com — 6079facf3673948d — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2088402@limexltd.com — cfcb32425bde01b5 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2089536@limexltd.com — afdc4724d22d96bd — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2090201@limexltd.com — dbc63abf008e1f37 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2091244@limexltd.com — bcfbbcb6b234006b — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2093302@limexltd.com — 7ebd9639be4fcaed — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2093610@limexltd.com — d7866c268dd623e5 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2095983@limexltd.com — 293043064dc9c536 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2096144@limexltd.com — ba186ca78ce19ad1 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2098181@limexltd.com — 2d01bd20796af6df — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2100540@limexltd.com — 3f9002b1b1787a70 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2100827@limexltd.com — edcdff2cf1a6fd36 — [Google Play] — 649.0₽
#   user2103655@limexltd.com — 666a14050f285414 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2105937@limexltd.com — d964e22325561fa9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2106049@limexltd.com — cc661fb02668b08f — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2106490@limexltd.com — 18dfee75a99a7bca — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2113014@limexltd.com — 651406020d7d220e — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2124718@limexltd.com — 3a8cc76c159baca5 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2125089@limexltd.com — e108024d4d797ce9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2127658@limexltd.com — ab9eee01e52c163c — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2130647@limexltd.com — 6a757ed6e183e7fe — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2135449@limexltd.com — feaacaed2cfde627 — [Google Play] — 649.0₽
#   user2138494@limexltd.com — 553d93d1465bc275 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2143457@limexltd.com — 3593bce2c48eee7e — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2146950@limexltd.com — 658c6ed9571c7499 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2149575@limexltd.com — 2d5035ab37e5e1b1 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2153054@limexltd.com — 06fe145bf7c1b5e6 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2155280@limexltd.com — 283f2eaac4776d4e — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2157807@limexltd.com — 54f7c434e00ccb61 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2158073@limexltd.com — 57ed8ebee3684ddb — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2159396@limexltd.com — 675b9552500e4007 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2159522@limexltd.com — 205e06b93b843f8e — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2173249@limexltd.com — dda3379b35abb1c9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2174705@limexltd.com — 56b48819b52ba167 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2174957@limexltd.com — 9c6e8f9b6bf68207 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2175741@limexltd.com — 39de7b044ab3fa34 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2177295@limexltd.com — f55beafab2af475b — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2181488@limexltd.com — 333f02aea6ba3dd1 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2191183@limexltd.com — fb17695c65476334 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2194683@limexltd.com — 1c47bbcc52a46f56 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2195698@limexltd.com — ce7ca237b697f490 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2196090@limexltd.com — dc128e8609a6c554 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2197525@limexltd.com — 95080a2fc453b5df — [unknown] — 649.0₽
#
# April 2025 — 18+ [463]:
#   efremovaelis7@gmail.com — c76d3e9d-17a5-4f7e-8948-e4cc0271717a — [unknown] — 349.0₽
#   user1974169@limexltd.com — 7a662709ea4c2806 — [Google Play] — 349.0₽
#   vasemin36@gmail.com — a0ab05e5-6d2f-4031-ac37-350c20fd7586 — [unknown] — 349.0₽
#
# April 2025 — PREMIER [477]:
#   user1898933@limexltd.com — 6910ae281bddfe42 — [unknown] — 399.0₽
#   user1942291@limexltd.com — de9c160dbb8c516e — [Google Play] — 399.0₽
#   user1958314@limexltd.com — f00af1f91fcf341b — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user1973966@limexltd.com — 0f38a548f8cd179b — [unknown] — 399.0₽
#   user1986447@limexltd.com — fea5f563eca2d711 — [Google Play] — 399.0₽
#   user1990290@limexltd.com — 4264f57ef97be202 — [PIX_Direct_10.03.25_Alternative] — 399.0₽
#   user1990346@limexltd.com — 5feb28bfbc52cc96 — [PIX Android push] — 399.0₽
#   user1996219@limexltd.com — 571691c7a5d0e773 — [PIX Android push] — 399.0₽
#   user1998228@limexltd.com — 79883ff0491d8754 — [PIX_Direct_10.03.25_Alternative] — 399.0₽
#   user2000062@limexltd.com — 557410aeda7777e3 — [PIX_Direct_10.03.25_Alternative] — 399.0₽
#   user2016141@limexltd.com — 702d3d2afe83aefe — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user2036679@limexltd.com — 35d7c654bc561095 — [Google Play] — 399.0₽
#
# April 2025 — START [470]:
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d — [PIX_Android_video_app_mid_roll] — 499.0₽
#   user1997710@limexltd.com — 1ff2e5f148e2d1a0 — [Google Play] — 499.0₽
#   user2050119@limexltd.com — 0ed87282d438c8ab — [Google Play] — 499.0₽
#
# April 2025 — Мегапикс [456]:
#   user1933891@limexltd.com — 12d79bcdb955c5b0 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1942494@limexltd.com — e6ef7bc4f0b5931c — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user1946876@limexltd.com — f4a3e3fbf5685a8 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1958818@limexltd.com — dbd3f019e9460bce — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user1971824@limexltd.com — eb4ddcef482ca50b — [PIX Android push] — 649.0₽
#   user1972216@limexltd.com — 535fd2dcbeaea51b — [PIX Android push] — 649.0₽
#   user1972370@limexltd.com — 98966d3af474c027 — [PIX Android push] — 649.0₽
#   user1972762@limexltd.com — c15e9f768c2062af — [PIX Android push] — 649.0₽
#   user1974519@limexltd.com — c0859f4d7e2ed0c6 — [Google Play] — 649.0₽
#   user1982408@limexltd.com — f7e7f70f57b7e7f6 — [Google Play] — 649.0₽
#   user1988680@limexltd.com — f036010c83d7f64f — [Google Play] — 649.0₽
#   user1990248@limexltd.com — a45ded42712b05d2 — [Google Play] — 649.0₽
#   user1991333@limexltd.com — 2a2e04e889112c26 — [PIX Android push] — 649.0₽
#   user1991886@limexltd.com — a673c48952a4ac04 — [PIX Android push] — 649.0₽
#   user1992530@limexltd.com — 8b315d64ef6e8d5c — [unknown] — 649.0₽
#   user1993377@limexltd.com — e61d0488f1ca6196 — [Google Play] — 649.0₽
#   user1993951@limexltd.com — 1b08a3ebce81f03d — [PIX Android push] — 649.0₽
#   user1998228@limexltd.com — 79883ff0491d8754 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2000062@limexltd.com — 557410aeda7777e3 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2000223@limexltd.com — eb8db3193378d879 — [PIX_Direct_10.03.25_Alternative] — 649.0₽
#   user2003114@limexltd.com — 7c6740099601861b — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2003744@limexltd.com — b96f7cc16dd43cbf — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2003856@limexltd.com — 993f17c99439a9c3 — [Google Play] — 649.0₽
#   user2004423@limexltd.com — d611ca8715809ec9 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2007447@limexltd.com — 51e1d888eb96c4f2 — [unknown] — 649.0₽
#   user2008035@limexltd.com — 10f6fb90bbea4405 — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2015952@limexltd.com — f718b63777b0439d — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2016554@limexltd.com — a03d4e1aecf0e33e — [Google Play] — 649.0₽
#   user2018500@limexltd.com — 523fdbc6610e0872 — [unknown] — 649.0₽
#   user2029427@limexltd.com — f5f048259ffb3a3e — [Google Play] — 649.0₽
#   user2029448@limexltd.com — 692183193829ad14 — [Google Play] — 649.0₽
#   user2030484@limexltd.com — caf6530df567b45f — [PIX Android push] — 649.0₽
#   user2030561@limexltd.com — a5a97b4e8cafbc03 — [PIX Android push] — 649.0₽
#   user2032269@limexltd.com — 6a68ae2425f1361e — [Google Play] — 649.0₽
#   user2033781@limexltd.com — 31cb2a059b249fdf — [unknown] — 649.0₽
#   user2039535@limexltd.com — ba9cac2f66e9b46a — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2041264@limexltd.com — 3a7f3c98150294e3 — [Pix_direct_19.02.25] — 649.0₽
#   user2042013@limexltd.com — 8b37077c455e260a — [Google Search] — 649.0₽
#   user2044365@limexltd.com — d6ade4216d7069ef — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2044477@limexltd.com — ed06662f083d63dd — [PIX_Android_video_app_mid_roll] — 649.0₽
#   user2053577@limexltd.com — d069437365fae0a1 — [PIX Android push] — 649.0₽
#
# March 2025 — 18+ [463]:
#   sasch.telminov@yandex.ru — 77c846d4-8b61-4345-a68c-3386ab96f3a5 — [unknown] — 349.0₽
#   user1897519@limexltd.com — b09c8a5293a5cc59 — [unknown] — 349.0₽
#   user1900291@limexltd.com — 777fc704f649055e — [unknown] — 349.0₽
#
# March 2025 — PREMIER [477]:
#   user1933891@limexltd.com — 12d79bcdb955c5b0 — [PIX_Android_video_app_mid_roll] — 399.0₽
#   user1952308@limexltd.com — b5a6b4c8d5dd0f7d — [PIX_Android_video_app_mid_roll] — 399.0₽
#
# March 2025 — КХЛ [484]:
#   Merzavecff210@gmail.com — 05e7c145-c2a0-48e3-b6f9-5515f46aa874 — [unknown] — 199.0₽
#
# March 2025 — Мегапикс [456]:
#   sasch.telminov@yandex.ru — f4c31551-6c3f-4bf6-9f64-6fe9e847e41c — [unknown] — 649.0₽
#   user1892787@limexltd.com — 770ac6ac89b637e8 — [unknown] — 649.0₽
#   user1903511@limexltd.com — 41bea2cec9501f3f — [unknown] — 649.0₽
#   user1905709@limexltd.com — 0c18cbdc80100ee1 — [unknown] — 649.0₽
#   user1907543@limexltd.com — d1844cf885ef0581 — [unknown] — 649.0₽
#   user1918260@limexltd.com — bfc275b41f749f39 — [unknown] — 649.0₽
#   user1938364@limexltd.com — 425c13cde7991343 — [unknown] — 649.0₽
#
# February 2025 — PREMIER [477]:
#   user1883771@limexltd.com — 3b53116adfc4d266 — [unknown] — 399.0₽
#
#
# Статистика по трекерам (переходы full) по месяцам:
#
# June 2025 — PIX_Android_video_app_mid_roll: 2 пользователей, 1298.0₽
# May 2025 — PIX_Android_video_app_mid_roll: 53 пользователей, 39288.0₽
# May 2025 — Google Play: 16 пользователей, 11629.0₽
# May 2025 — PIX_Direct_10.03.25_Alternative: 8 пользователей, 7536.0₽
# May 2025 — unknown: 4 пользователей, 3494.0₽
# May 2025 — PIX Android push: 2 пользователей, 1896.0₽
# May 2025 — PIX_Android_video_app_mid_roll_Inspector_Gav: 1 пользователей, 1048.0₽
# May 2025 — PIX_Android_video_app_pre_roll: 1 пользователей, 399.0₽
# May 2025 — PIX Android баннеры: 1 пользователей, 349.0₽
# April 2025 — Google Play: 16 пользователей, 12726.0₽
# April 2025 — PIX_Android_video_app_mid_roll: 14 пользователей, 8835.0₽
# April 2025 — PIX Android push: 12 пользователей, 7288.0₽
# April 2025 — unknown: 8 пользователей, 4741.0₽
# April 2025 — PIX_Direct_10.03.25_Alternative: 5 пользователей, 3793.0₽
# April 2025 — Google Search: 1 пользователей, 649.0₽
# April 2025 — Pix_direct_19.02.25: 1 пользователей, 649.0₽
# March 2025 — unknown: 10 пользователей, 5789.0₽
# March 2025 — PIX_Android_video_app_mid_roll: 2 пользователей, 798.0₽
# February 2025 — unknown: 1 пользователей, 399.0₽
#
# Статистика по повторным платежам (repeat) по месяцам и трекерам:
#
# June 2025 — PIX_Android_video_app_mid_roll: 1 повторных платежей, 649.0₽
# May 2025 — Google Play: 18 повторных платежей, 8832.0₽
# May 2025 — unknown: 15 повторных платежей, 7285.0₽
# May 2025 — PIX_Android_video_app_mid_roll: 10 повторных платежей, 5590.0₽
# May 2025 — PIX Android push: 8 повторных платежей, 4692.0₽
# May 2025 — PIX_Direct_10.03.25_Alternative: 3 повторных платежей, 1697.0₽
# May 2025 — Google Search: 1 повторных платежей, 649.0₽
# May 2025 — Pix_direct_19.02.25: 1 повторных платежей, 649.0₽
# April 2025 — unknown: 10 повторных платежей, 4890.0₽
# April 2025 — PIX_Android_video_app_mid_roll: 2 повторных платежей, 798.0₽
# March 2025 — unknown: 1 повторных платежей, 399.0₽
